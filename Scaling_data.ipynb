# %% [markdown]
# <a href="https://colab.research.google.com/github/veranika-izrailyan/Machine_Learning/blob/main/Scaling_data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
boston_df=pd.read_csv('boston.csv')
boston_df.head()
# Out:
#       CRIM    ZN  INDUS  CHAS     NX  ...  TAX  PTRATIO       B  LSTAT  MEDV
# 0  0.00632  18.0   2.31     0  0.538  ...  296     15.3  396.90   4.98  24.0
# 1  0.02731   0.0   7.07     0  0.469  ...  242     17.8  396.90   9.14  21.6
# 2  0.02729   0.0   7.07     0  0.469  ...  242     17.8  392.83   4.03  34.7
# 3  0.03237   0.0   2.18     0  0.458  ...  222     18.7  394.63   2.94  33.4
# 4  0.06905   0.0   2.18     0  0.458  ...  222     18.7  396.90   5.33  36.2
#
# [5 rows x 14 columns]

# %%
boston_df.describe()
# Out:
#              CRIM          ZN       INDUS  ...           B       LSTAT        MEDV
# count  506.000000  506.000000  506.000000  ...  506.000000  506.000000  506.000000
# mean     3.613524   11.363636   11.136779  ...  356.674032   12.653063   22.532806
# std      8.601545   23.322453    6.860353  ...   91.294864    7.141062    9.197104
# min      0.006320    0.000000    0.460000  ...    0.320000    1.730000    5.000000
# 25%      0.082045    0.000000    5.190000  ...  375.377500    6.950000   17.025000
# 50%      0.256510    0.000000    9.690000  ...  391.440000   11.360000   21.200000
# 75%      3.677082   12.500000   18.100000  ...  396.225000   16.955000   25.000000
# max     88.976200  100.000000   27.740000  ...  396.900000   37.970000   50.000000
#
# [8 rows x 14 columns]

# %%
import matplotlib.pyplot as plt
import seaborn as sns

data_melted= pd.melt(boston_df)
fig, ax =plt.subplots(figsize=(14,10))
ax = sns.boxplot(x="variable", y="value", data=data_melted)
ax.set_xlabel("")
ax.set_ylabel('MEDV')
plt.show()

# %%
x=boston_df.drop(['MEDV'], axis=1)
y=boston_df['MEDV']

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
scaler.fit(x)
X_scaled=scaler.transform(x)

X_scaled
# Out:
# array([[-0.41978194,  0.28482986, -1.2879095 , ..., -1.45900038,
#          0.44105193, -1.0755623 ],
#        [-0.41733926, -0.48772236, -0.59338101, ..., -0.30309415,
#          0.44105193, -0.49243937],
#        [-0.41734159, -0.48772236, -0.59338101, ..., -0.30309415,
#          0.39642699, -1.2087274 ],
#        ...,
#        [-0.41344658, -0.48772236,  0.11573841, ...,  1.17646583,
#          0.44105193, -0.98304761],
#        [-0.40776407, -0.48772236,  0.11573841, ...,  1.17646583,
#          0.4032249 , -0.86530163],
#        [-0.41500016, -0.48772236,  0.11573841, ...,  1.17646583,
#          0.44105193, -0.66905833]])

# %%
pd.DataFrame(X_scaled, columns=list(x))
# Out:
#          CRIM        ZN     INDUS  ...   PTRATIO         B     LSTAT
# 0   -0.419782  0.284830 -1.287909  ... -1.459000  0.441052 -1.075562
# 1   -0.417339 -0.487722 -0.593381  ... -0.303094  0.441052 -0.492439
# 2   -0.417342 -0.487722 -0.593381  ... -0.303094  0.396427 -1.208727
# 3   -0.416750 -0.487722 -1.306878  ...  0.113032  0.416163 -1.361517
# 4   -0.412482 -0.487722 -1.306878  ...  0.113032  0.441052 -1.026501
# ..        ...       ...       ...  ...       ...       ...       ...
# 501 -0.413229 -0.487722  0.115738  ...  1.176466  0.387217 -0.418147
# 502 -0.415249 -0.487722  0.115738  ...  1.176466  0.441052 -0.500850
# 503 -0.413447 -0.487722  0.115738  ...  1.176466  0.441052 -0.983048
# 504 -0.407764 -0.487722  0.115738  ...  1.176466  0.403225 -0.865302
# 505 -0.415000 -0.487722  0.115738  ...  1.176466  0.441052 -0.669058
#
# [506 rows x 13 columns]

# %%
df_scaled=pd.DataFrame(X_scaled, columns=list(x))

# %%
df_scaled_melted=pd.melt(df_scaled)

# %%
fig, ax =plt.subplots(figsize=(14,10))
ax = sns.boxplot(x="variable", y="value", data=df_scaled_melted)
ax.set_xlabel("")
ax.set_ylabel('MEDV')
plt.show()

# %%
# Alternative using fit_transform

scaler=StandardScaler()
X_scaled_02 = scaler.fit_transform(x)
pd.DataFrame(X_scaled_02, columns=list(x)).head()
# Out:
#        CRIM        ZN     INDUS  ...   PTRATIO         B     LSTAT
# 0 -0.419782  0.284830 -1.287909  ... -1.459000  0.441052 -1.075562
# 1 -0.417339 -0.487722 -0.593381  ... -0.303094  0.441052 -0.492439
# 2 -0.417342 -0.487722 -0.593381  ... -0.303094  0.396427 -1.208727
# 3 -0.416750 -0.487722 -1.306878  ...  0.113032  0.416163 -1.361517
# 4 -0.412482 -0.487722 -1.306878  ...  0.113032  0.441052 -1.026501
#
# [5 rows x 13 columns]

# %%
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import RobustScaler
transformer = Pipeline(
    [
     ('scaler', StandardScaler()),
     ('robust', RobustScaler())
    ]
)

transformer.fit(x)
pd.DataFrame(transformer.transform(x), columns=list(x)).head()
# Out:
#        CRIM    ZN     INDUS  CHAS  ...       TAX   PTRATIO         B     LSTAT
# 0 -0.069593  1.44 -0.571650   0.0  ... -0.087855 -1.339286  0.261902 -0.637681
# 1 -0.063755  0.00 -0.202943   0.0  ... -0.227390 -0.446429  0.261902 -0.221889
# 2 -0.063760  0.00 -0.202943   0.0  ... -0.227390 -0.446429  0.066675 -0.732634
# 3 -0.062347  0.00 -0.581720   0.0  ... -0.279070 -0.125000  0.153016 -0.841579
# 4 -0.052144  0.00 -0.581720   0.0  ... -0.279070 -0.125000  0.261902 -0.602699
#
# [5 rows x 13 columns]
